# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv("BootstrappedAndNoOutlierAndStructuredData.csv", encoding = "utf-8",sep=",")

# %%
data = data.drop('Unnamed: 0', axis = 1)
data
# Out:
#       Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0            3920       2586           1028           619          56     98
# 1            5394       2727           1838          1174          78    194
# 2            4528       2700            621           932          73    172
# 3            2518       1704            255           279          37     96
# 4            3884       2046           1214           329          43     74
# ...           ...        ...            ...           ...         ...    ...
# 1877         4467       1910           1880           492          60     89
# 1878         4115       2609           1104           178          46    122
# 1879         2621       1543            599           333          25     22
# 1880         5055       2017           2351           298         108    101
# 1881         6168       2177           3450           153         296     82
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1882 entries, 0 to 1881
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Impressions     1882 non-null   int64
#  1   From Home       1882 non-null   int64
#  2   From Hashtags   1882 non-null   int64
#  3   From Explore    1882 non-null   int64
#  4   From Other      1882 non-null   int64
#  5   Saves           1882 non-null   int64
#  6   Comments        1882 non-null   int64
#  7   Shares          1882 non-null   int64
#  8   Likes           1882 non-null   int64
#  9   Profile Visits  1882 non-null   int64
#  10  Follows         1882 non-null   int64
# dtypes: int64(11)
# memory usage: 161.9 KB

# %%
data.corr()
# Out:
#                 Impressions  From Home  From Hashtags  From Explore  \
# Impressions        1.000000   0.263349       0.906705      0.234609
# From Home          0.263349   1.000000      -0.101958      0.376294
# From Hashtags      0.906705  -0.101958       1.000000     -0.080857
# From Explore       0.234609   0.376294      -0.080857      1.000000
# From Other         0.226662  -0.006845       0.161094     -0.013255
# Saves              0.426150   0.620641       0.170251      0.385296
# Comments           0.347886   0.353149       0.256856      0.159404
# Shares             0.095982   0.382297      -0.091641      0.266426
# Likes              0.788800   0.543968       0.624341      0.257852
# Profile Visits     0.617421  -0.091481       0.668360     -0.005146
# Follows            0.685950   0.063134       0.675300     -0.024862
#
#                 From Other     Saves  Comments    Shares     Likes  \
# Impressions       0.226662  0.426150  0.347886  0.095982  0.788800
# ...

# %%
f, axes = plt.subplots(1,1,figsize=(20,20))
sb.heatmap(data.corr(),vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >
