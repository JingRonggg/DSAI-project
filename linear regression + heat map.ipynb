# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv("BootstrappedAndNoOutlierAndStructuredData.csv", encoding = "utf-8",sep=",")

# %%
data = data.drop('Unnamed: 0', axis = 1)
data
# Out:
#       Impressions  Comments  Shares  Likes
# 0            3920         9       5    162
# 1            5394         7      14    224
# 2            4021        11       1    131
# 3            4528        10       7    213
# 4            2518         5       4    123
# ...           ...       ...     ...    ...
# 2238         4467         3      16    149
# 2239         4115         6       3    191
# 2240         2621         5       1     76
# 2241         5055         7      11    159
# 2242         6168         6       6    151
#
# [2243 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2243 entries, 0 to 2242
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Impressions  2243 non-null   int64
#  1   Comments     2243 non-null   int64
#  2   Shares       2243 non-null   int64
#  3   Likes        2243 non-null   int64
# dtypes: int64(4)
# memory usage: 70.2 KB

# %%
data.corr()
# Out:
#              Impressions  Comments    Shares     Likes
# Impressions     1.000000  0.334292  0.223006  0.782182
# Comments        0.334292  1.000000  0.111854  0.421072
# Shares          0.223006  0.111854  1.000000  0.430066
# Likes           0.782182  0.421072  0.430066  1.000000

# %%
f, axes = plt.subplots(1,1,figsize=(20,20))
sb.heatmap(data.corr(),vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <Axes: >
